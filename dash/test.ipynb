# %%
import pandas as pd
df = pd.read_csv('../v2x_data/FinalCleanedDataIO.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# device                         int64
# endlatitude                  float64
# endlocaltime                   int64
# endlongitude                 float64
# filedate                       int64
# filetimeutc                    int64
# numbsmtx                     float64
# numinforms                   float64
# numintersectionencounters    float64
# numnormalbsmrx                 int64
# numwarnings                    int64
# startlatitude                float64
# startlocaltime               float64
# startlongitude               float64
# utctime                        int64
# uuid                          object
# tripid                        object
# tripdistance                 float64
# avgspeed                     float64
# utctime(datetime)             object
# tripdistance_miles           float64
# avgspeed_mph                 float64
# endlocaltime(datetime)        object
# startlocaltime(datetime)      object
# dtype: object

# %%
df['dayofweek'] = \
pd.to_datetime(df['utctime(datetime)']).dt.day_name()

# %%
x = df.groupby(['dayofweek'])[avgspeed].mean()
# Out:
# C:\Users\21jan\AppData\Local\Temp\ipykernel_1692\3598121893.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x = df.groupby(['dayofweek']).mean()

# %%
x
# Out:
#             Unnamed: 0         device  endlatitude  endlocaltime  \
# dayofweek
# Friday     1087.814935  101657.545455    40.159056  5.871725e+07
# Monday     1082.015432  101723.049383    40.328561  5.817459e+07
# Saturday   1097.549865  101754.876011    40.188096  5.686128e+07
# Sunday     1155.253165  101641.136076    40.187921  6.014470e+07
# Thursday   1084.592308  101714.284615    40.207181  5.759754e+07
# Tuesday    1104.961783  101694.853503    40.224002  5.656109e+07
# Wednesday  1081.684039  101716.019544    40.146695  5.725434e+07
#
#            endlongitude      filedate    filetimeutc      numbsmtx  \
# dayofweek
# Friday       -83.218135  2.020062e+07  160357.090909  11038.527687
# Monday       -83.265045  2.020061e+07  159687.092593  10663.167183
# Saturday     -83.111571  2.020061e+07  155972.889488   9904.675824
# Sunday       -83.096640  2.020062e+07  164099.202532  10083.116883
# Thursday     -83.298955  2.020061e+07  159397.346154  11228.046512
# Tuesday      -83.314401  2.020061e+07  154901.777070  12411.961783
# Wednesday    -83.281654  2.020061e+07  157163.866450  13047.473510
#
#            numinforms  numintersectionencounters  numnormalbsmrx  numwarnings  \
# dayofweek
# Friday       0.025974                   0.656357       62.392857     0.077922
# Monday       0.006173                   0.615132       29.413580     0.021605
# Saturday     0.005391                   0.578348       50.900270     0.008086
# Sunday       0.063291                   0.545455       46.208861     0.031646
# Thursday     0.542308                   0.547325      187.123077     0.030769
# Tuesday      0.372611                   0.691781      188.464968     0.035032
# Wednesday    1.238562                   0.834459      310.013029     0.048860
#
#            startlatitude  startlocaltime  startlongitude       utctime  \
# dayofweek
# Friday         40.175906    5.856971e+07      -83.206721  1.592302e+12
# Monday         40.305783    5.821827e+07      -83.215264  1.592187e+12
# Saturday       40.181537    5.664275e+07      -83.109825  1.592163e+12
# Sunday         40.206173    5.988999e+07      -83.096295  1.592375e+12
# Thursday       40.185726    5.810576e+07      -83.262725  1.592171e+12
# Tuesday        40.202896    5.631904e+07      -83.299160  1.592043e+12
# Wednesday      40.130860    5.702460e+07      -83.269218  1.592090e+12
#
#            tripdistance   avgspeed  tripdistance_miles  avgspeed_mph
# dayofweek
# Friday     19145.570725  16.351277           11.896502     36.576754
# Monday     16817.537910  16.748769           10.449930     37.465918
# Saturday   17000.437289  12.240914           10.563579     27.382137
# Sunday     14695.251208  12.412507            9.131203     27.765980
# Thursday   20977.030382  18.089676           13.034518     40.465441
# Tuesday    20381.207199  17.423774           12.664291     38.975860
# Wednesday  22833.620755  17.757687           14.188150     39.722802
